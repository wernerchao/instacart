# %%
# %matplotlib inline
import matplotlib.pyplot as plt

import time
import numpy as np
import pandas as pd

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import StratifiedKFold, learning_curve
from sklearn.metrics import f1_score, log_loss

import xgboost as xgb
IDIR = '../../features/'

# %%
# %%time

df_train = pd.read_csv('../../features/df_train_feats_38.csv')
order_id = df_train['order_id']
product_id = df_train['product_id']

# labels = pd.read_csv('../../features/labels_feats_38.csv')
labels = df_train['reordered']
df_train = df_train.drop(['order_id', 'product_id', 'user_id', \
                          'product_id_r', 'order_id_r', 'eval_set', \
                          'reordered', 'ord_prod_id', 'ord_prod_id_r'], axis=1)
# Out:
# CPU times: user 1min 11s, sys: 8.71 s, total: 1min 20s
# Wall time: 1min 21s

# %%
# %%time

print('formating for xgb')
d_train = xgb.DMatrix(df_train, label = labels)
# Out:
# formating for xgb
# CPU times: user 9.71 s, sys: 15.6 s, total: 25.3 s
# Wall time: 30.3 s

# %%
params = {
  "objective"           : "reg:logistic",
  "eval_metric"         : "logloss",
  "eta"                 : 0.2,
  "max_depth"           : 6,
  "min_child_weight"    : 10,
  "gamma"               : 0.70,
  "subsample"           : 0.76,
  "colsample_bytree"    : 0.95,
  "alpha"               : 2e-05,
  "lambda"              : 10
}

# %%
# n_folds = 2
ROUNDS = 500
estop = 15
training_examples = []
hist_train = []
hist_val = []
start_time = time.time()

for n_folds in range(2, 11, 1):
    print('XGB train...')
    skf = StratifiedKFold(n_splits = n_folds, random_state=None, shuffle=False)
    for train_index, val_index in skf.split(df_train, labels):
        X_train, X_val = df_train.iloc[train_index, :], df_train.iloc[val_index, :]
        y_train, y_val = labels[train_index], labels[val_index]

        print('formating for xgb')
        d_train = xgb.DMatrix(X_train, label = y_train)
        d_valid = xgb.DMatrix(X_val, label = y_val)
        watchlist = [(d_train, 'train'), (d_valid, 'val')]

        print('Training...')
        bst = xgb.train(params = params, \
                        dtrain = d_train, \
                        num_boost_round = ROUNDS, \
                        evals = watchlist, \
                        verbose_eval = 10, \
                        early_stopping_rounds = estop)

        pred_val = bst.predict(xgb.DMatrix(X_val))
        pred_train = bst.predict(xgb.DMatrix(X_train))

        loss_train = log_loss(y_train, pred_train)
        loss_val = log_loss(y_val, pred_val)
        break

    # Save XGB model.
    stamp = ''
    for i, item in enumerate(list(params.values())):
        if i <= 1:
            stamp = '_' + str(n_folds) + '_' + str(ROUNDS)
            continue
        else:
            stamp += '_' + str(item)
    print('xgb{}_feats38'.format(stamp))
    bst.save_model('xgb{}_feats38'.format(stamp))

    # Save the training history for learning curve
    training_examples.append(X_train.shape[0])
    hist_train.append(loss_train)
    hist_val.append(loss_val)
    print('Folds: ', n_folds, ' - Time Elapsed: ', time.time() - start_time)
# Out:
# XGB train...
# formating for xgb
# Training...
# [0]	train-logloss:0.565265	val-logloss:0.565126
# Multiple eval metrics have been passed: 'val-logloss' will be used for early stopping.
#
# Will train until val-logloss hasn't improved in 15 rounds.
# [10]	train-logloss:0.264911	val-logloss:0.264348
# [20]	train-logloss:0.247178	val-logloss:0.246647
# [30]	train-logloss:0.245498	val-logloss:0.245173
# [40]	train-logloss:0.244876	val-logloss:0.244806
# [50]	train-logloss:0.244324	val-logloss:0.244494
# [60]	train-logloss:0.243981	val-logloss:0.244412
# [70]	train-logloss:0.243648	val-logloss:0.244306
# [80]	train-logloss:0.243372	val-logloss:0.244233
# [90]	train-logloss:0.243061	val-logloss:0.244163
# [100]	train-logloss:0.242828	val-logloss:0.244127
# [110]	train-logloss:0.242549	val-logloss:0.244094
# Stopping. Best iteration:
# [102]	train-logloss:0.242744	val-logloss:0.244093
#
# xgb_2_500_0.2_6_10_0.7_0.76_0.95_2e-05_10_feats38
# Folds:  2  - Time Elapsed:  539.3184728622437
# XGB train...
# formating for xgb
# Training...
# [0]	train-logloss:0.565241	val-logloss:0.56512
# Multiple eval metrics have been passed: 'val-logloss' will be used for early stopping.
#
# Will train until val-logloss hasn't improved in 15 rounds.
# [10]	train-logloss:0.26471	val-logloss:0.264143
# [20]	train-logloss:0.246981	val-logloss:0.246404
# [30]	train-logloss:0.245318	val-logloss:0.244918
# [40]	train-logloss:0.244757	val-logloss:0.244555
# [50]	train-logloss:0.244387	val-logloss:0.244354
# [60]	train-logloss:0.244017	val-logloss:0.244205
# [70]	train-logloss:0.243745	val-logloss:0.244105
# [80]	train-logloss:0.243504	val-logloss:0.244019
# [90]	train-logloss:0.243288	val-logloss:0.243975
# [100]	train-logloss:0.24308	val-logloss:0.243934
# [110]	train-logloss:0.242829	val-logloss:0.243888
# [120]	train-logloss:0.242597	val-logloss:0.243844
# [130]	train-logloss:0.242404	val-logloss:0.243832
# [140]	train-logloss:0.242192	val-logloss:0.243818
# [150]	train-logloss:0.242017	val-logloss:0.243814
# Stopping. Best iteration:
# [136]	train-logloss:0.242268	val-logloss:0.243807
#
# xgb_3_500_0.2_6_10_0.7_0.76_0.95_2e-05_10_feats38
# Folds:  3  - Time Elapsed:  1409.3693721294403
# XGB train...
# formating for xgb
# Training...
# [0]	train-logloss:0.565187	val-logloss:0.5651
# Multiple eval metrics have been passed: 'val-logloss' will be used for early stopping.
#
# Will train until val-logloss hasn't improved in 15 rounds.
# [10]	train-logloss:0.264631	val-logloss:0.264163
# [20]	train-logloss:0.24686	val-logloss:0.246395
# [30]	train-logloss:0.245295	val-logloss:0.244969
# [40]	train-logloss:0.244613	val-logloss:0.244526
# [50]	train-logloss:0.244253	val-logloss:0.244343
# [60]	train-logloss:0.243999	val-logloss:0.244249
# [70]	train-logloss:0.243663	val-logloss:0.244083
# [80]	train-logloss:0.243397	val-logloss:0.244009
# [90]	train-logloss:0.243207	val-logloss:0.243977
# [100]	train-logloss:0.242985	val-logloss:0.243937
# [110]	train-logloss:0.242781	val-logloss:0.243858
# [120]	train-logloss:0.242579	val-logloss:0.243847
# [130]	train-logloss:0.242427	val-logloss:0.24383
# [140]	train-logloss:0.242282	val-logloss:0.243814
# [150]	train-logloss:0.242081	val-logloss:0.2438
# [160]	train-logloss:0.241919	val-logloss:0.243784
# [170]	train-logloss:0.241775	val-logloss:0.243802
# Stopping. Best iteration:
# [160]	train-logloss:0.241919	val-logloss:0.243784
#
# xgb_4_500_0.2_6_10_0.7_0.76_0.95_2e-05_10_feats38
# Folds:  4  - Time Elapsed:  2533.543000936508
# XGB train...
# formating for xgb
# Training...
# [0]	train-logloss:0.565173	val-logloss:0.565184
# Multiple eval metrics have been passed: 'val-logloss' will be used for early stopping.
#
# Will train until val-logloss hasn't improved in 15 rounds.
# [10]	train-logloss:0.264549	val-logloss:0.264407
# [20]	train-logloss:0.246935	val-logloss:0.246803
# [30]	train-logloss:0.245222	val-logloss:0.245255
# [40]	train-logloss:0.244644	val-logloss:0.244838
# [50]	train-logloss:0.244259	val-logloss:0.244635
# [60]	train-logloss:0.243952	val-logloss:0.244455
# [70]	train-logloss:0.243697	val-logloss:0.244325
# [80]	train-logloss:0.243493	val-logloss:0.24427
# [90]	train-logloss:0.243247	val-logloss:0.244176
# [100]	train-logloss:0.243072	val-logloss:0.244143
# [110]	train-logloss:0.242856	val-logloss:0.244113
# [120]	train-logloss:0.242669	val-logloss:0.244088
# [130]	train-logloss:0.242514	val-logloss:0.244083
# [140]	train-logloss:0.242353	val-logloss:0.244039
# [150]	train-logloss:0.242198	val-logloss:0.244024
# [160]	train-logloss:0.24203	val-logloss:0.244007
# [170]	train-logloss:0.241885	val-logloss:0.243988
# [180]	train-logloss:0.241736	val-logloss:0.243984
# [190]	train-logloss:0.241583	val-logloss:0.243981
# Stopping. Best iteration:
# [184]	train-logloss:0.241674	val-logloss:0.24397
#
# xgb_5_500_0.2_6_10_0.7_0.76_0.95_2e-05_10_feats38
# Folds:  5  - Time Elapsed:  3848.66247010231
# XGB train...
# formating for xgb
# Training...
# [0]	train-logloss:0.565204	val-logloss:0.565203
# Multiple eval metrics have been passed: 'val-logloss' will be used for early stopping.
#
# Will train until val-logloss hasn't improved in 15 rounds.
# [10]	train-logloss:0.264464	val-logloss:0.264225
# [20]	train-logloss:0.246863	val-logloss:0.246648
# [30]	train-logloss:0.245293	val-logloss:0.245211
# [40]	train-logloss:0.244629	val-logloss:0.244765
# [50]	train-logloss:0.244269	val-logloss:0.244563
# [60]	train-logloss:0.243988	val-logloss:0.244442
# [70]	train-logloss:0.243724	val-logloss:0.244325
# [80]	train-logloss:0.243546	val-logloss:0.244262
# [90]	train-logloss:0.243325	val-logloss:0.244206
# [100]	train-logloss:0.243116	val-logloss:0.244137
# [110]	train-logloss:0.242949	val-logloss:0.244108
# [120]	train-logloss:0.242728	val-logloss:0.244028
# [130]	train-logloss:0.242526	val-logloss:0.243996
# [140]	train-logloss:0.242352	val-logloss:0.243966
# [150]	train-logloss:0.242208	val-logloss:0.243946
# [160]	train-logloss:0.242051	val-logloss:0.243926
# [170]	train-logloss:0.241902	val-logloss:0.243937
# Stopping. Best iteration:
# [158]	train-logloss:0.242084	val-logloss:0.243922
#
# xgb_6_500_0.2_6_10_0.7_0.76_0.95_2e-05_10_feats38
# Folds:  6  - Time Elapsed:  5026.0634479522705
# XGB train...
# formating for xgb
# Training...
# [0]	train-logloss:0.565209	val-logloss:0.56521
# Multiple eval metrics have been passed: 'val-logloss' will be used for early stopping.
#
# Will train until val-logloss hasn't improved in 15 rounds.
# [10]	train-logloss:0.264453	val-logloss:0.264324
# [20]	train-logloss:0.246832	val-logloss:0.246736
# [30]	train-logloss:0.24521	val-logloss:0.24525
# [40]	train-logloss:0.244661	val-logloss:0.244869
# [50]	train-logloss:0.244268	val-logloss:0.244641
# [60]	train-logloss:0.243997	val-logloss:0.244524
# [70]	train-logloss:0.243697	val-logloss:0.244365
# [80]	train-logloss:0.243464	val-logloss:0.244283
# [90]	train-logloss:0.243283	val-logloss:0.24423
# [100]	train-logloss:0.243077	val-logloss:0.244158
# [110]	train-logloss:0.242882	val-logloss:0.244128
# [120]	train-logloss:0.242677	val-logloss:0.244081
# [130]	train-logloss:0.242489	val-logloss:0.244031
# [140]	train-logloss:0.242332	val-logloss:0.243991
# [150]	train-logloss:0.242184	val-logloss:0.243995
# [160]	train-logloss:0.242041	val-logloss:0.243997
# Stopping. Best iteration:
# [147]	train-logloss:0.242236	val-logloss:0.243985
#
# xgb_7_500_0.2_6_10_0.7_0.76_0.95_2e-05_10_feats38
# Folds:  7  - Time Elapsed:  6169.22984790802
# XGB train...
# formating for xgb
# Training...
# [0]	train-logloss:0.565197	val-logloss:0.565154
# Multiple eval metrics have been passed: 'val-logloss' will be used for early stopping.
#
# Will train until val-logloss hasn't improved in 15 rounds.
# [10]	train-logloss:0.264507	val-logloss:0.264242
# [20]	train-logloss:0.246833	val-logloss:0.246593
# [30]	train-logloss:0.245207	val-logloss:0.245108
# [40]	train-logloss:0.244657	val-logloss:0.244774
# [50]	train-logloss:0.244254	val-logloss:0.244533
# [60]	train-logloss:0.243983	val-logloss:0.244437
# [70]	train-logloss:0.243774	val-logloss:0.244349
# [80]	train-logloss:0.243523	val-logloss:0.244241
# [90]	train-logloss:0.243336	val-logloss:0.244182
# [100]	train-logloss:0.243152	val-logloss:0.24413
# [110]	train-logloss:0.24294	val-logloss:0.244057
# [120]	train-logloss:0.242754	val-logloss:0.244022
# [130]	train-logloss:0.242575	val-logloss:0.244021
# [140]	train-logloss:0.242405	val-logloss:0.243961
# [150]	train-logloss:0.242245	val-logloss:0.243949
# [160]	train-logloss:0.242111	val-logloss:0.24394
# [170]	train-logloss:0.24197	val-logloss:0.243937
# [180]	train-logloss:0.241833	val-logloss:0.243922
# [190]	train-logloss:0.241706	val-logloss:0.243906
# [200]	train-logloss:0.241562	val-logloss:0.243891
# [210]	train-logloss:0.241409	val-logloss:0.243906
# Stopping. Best iteration:
# [199]	train-logloss:0.241576	val-logloss:0.243885
#
# xgb_8_500_0.2_6_10_0.7_0.76_0.95_2e-05_10_feats38
# Folds:  8  - Time Elapsed:  7686.735204935074
# XGB train...
# formating for xgb
# Training...
# [0]	train-logloss:0.565159	val-logloss:0.565119
# Multiple eval metrics have been passed: 'val-logloss' will be used for early stopping.
#
# Will train until val-logloss hasn't improved in 15 rounds.
# [10]	train-logloss:0.264478	val-logloss:0.264322
# [20]	train-logloss:0.246904	val-logloss:0.246753
# [30]	train-logloss:0.245211	val-logloss:0.245208
# [40]	train-logloss:0.244659	val-logloss:0.244775
# [50]	train-logloss:0.244303	val-logloss:0.244548
# [60]	train-logloss:0.244037	val-logloss:0.244438
# [70]	train-logloss:0.243772	val-logloss:0.244322
# [80]	train-logloss:0.243566	val-logloss:0.244224
# [90]	train-logloss:0.243299	val-logloss:0.244085
# [100]	train-logloss:0.243108	val-logloss:0.244038
# [110]	train-logloss:0.242928	val-logloss:0.244002
# [120]	train-logloss:0.242755	val-logloss:0.243988
# [130]	train-logloss:0.242572	val-logloss:0.243941
# [140]	train-logloss:0.242415	val-logloss:0.243921
# [150]	train-logloss:0.242274	val-logloss:0.243896
# [160]	train-logloss:0.242152	val-logloss:0.243879
# [170]	train-logloss:0.24203	val-logloss:0.243866
# Stopping. Best iteration:
# [164]	train-logloss:0.242095	val-logloss:0.243864
#
# xgb_9_500_0.2_6_10_0.7_0.76_0.95_2e-05_10_feats38
# Folds:  9  - Time Elapsed:  8973.15851688385
# XGB train...
# formating for xgb
# Training...
# [0]	train-logloss:0.56517	val-logloss:0.565205
# Multiple eval metrics have been passed: 'val-logloss' will be used for early stopping.
#
# Will train until val-logloss hasn't improved in 15 rounds.
# [10]	train-logloss:0.264453	val-logloss:0.264542
# [20]	train-logloss:0.246825	val-logloss:0.246935
# [30]	train-logloss:0.24522	val-logloss:0.245493
# [40]	train-logloss:0.244593	val-logloss:0.245056
# [50]	train-logloss:0.244293	val-logloss:0.244888
# [60]	train-logloss:0.244018	val-logloss:0.244768
# [70]	train-logloss:0.243763	val-logloss:0.24465
# [80]	train-logloss:0.243517	val-logloss:0.244568
# [90]	train-logloss:0.243339	val-logloss:0.244509
# [100]	train-logloss:0.243166	val-logloss:0.244452
# [110]	train-logloss:0.243005	val-logloss:0.244431
# [120]	train-logloss:0.242828	val-logloss:0.244393
# [130]	train-logloss:0.242604	val-logloss:0.24432
# [140]	train-logloss:0.242447	val-logloss:0.244292
# [150]	train-logloss:0.242309	val-logloss:0.24428
# [160]	train-logloss:0.242181	val-logloss:0.244269
# [170]	train-logloss:0.242028	val-logloss:0.244274
# [180]	train-logloss:0.241866	val-logloss:0.244284
# Stopping. Best iteration:
# [166]	train-logloss:0.242093	val-logloss:0.244267
#
# xgb_10_500_0.2_6_10_0.7_0.76_0.95_2e-05_10_feats38
# Folds:  10  - Time Elapsed:  10381.733881950378

# %%
# training_examples, hist_train, hist_val
_ = plt.figure(figsize=(16, 8))
_ = plt.plot(training_examples, hist_train, label='train')
_ = plt.plot(training_examples, hist_val, label='val')
_ = plt.legend()

# %%
min(hist_val)
hist_val
# Out:
# [0.24411533299519261,
#  0.24381403504062421,
#  0.24380506433817417,
#  0.24398232276874646,
#  0.24393428974468248,
#  0.24399451413002332,
#  0.24389284943821124,
#  0.24387168378526838,
#  0.24428344897743964]

# %% [markdown]
# # Make Prediction

# %%
# Directly load joined data.

df_test = pd.read_csv(IDIR + 'df_test_feats_38.csv')
print(df_test.shape)

test_order_id = df_test['order_id']
test_product_id = df_test['product_id']

df_test = df_test.drop(['order_id', 'product_id', 'user_id', \
                          'product_id_r', 'order_id_r', 'eval_set', \
                          'reordered', 'ord_prod_id', 'ord_prod_id_r'], axis=1)

df_test.head()
# Out:
# (4833292, 47)
#    user_total_orders  user_total_items  total_distinct_items  \
# 0                 13                88                    33
# 1                 13                88                    33
# 2                 13                88                    33
# 3                 13                88                    33
# 4                 13                88                    33
#
#    user_average_days_between_orders  user_average_basket  order_hour_of_day  \
# 0                              12.0             6.769231                 15
# 1                              12.0             6.769231                 15
# 2                              12.0             6.769231                 15
# 3                              12.0             6.769231                 15
# 4                              12.0             6.769231                 15
#
#    days_since_prior_order  days_since_ratio  aisle_id  department_id  \
# 0                    11.0          0.916667        91             16
# 1                    11.0          0.916667        91             16
# 2                    11.0          0.916667        83              4
# 3                    11.0          0.916667       123              4
# 4                    11.0          0.916667        83              4
#
#                 ...                 user_period  user_mean_days_since_prior  \
# 0               ...                         133                   12.090909
# 1               ...                         133                   12.090909
# 2               ...                         133                   12.090909
# 3               ...                         133                   12.090909
# 4               ...                         133                   12.090909
#
#    user_total_products  user_reorder_ratio  user_distinct_products  \
# 0                   88            0.705128                      33
# 1                   88            0.705128                      33
# 2                   88            0.705128                      33
# 3                   88            0.705128                      33
# 4                   88            0.705128                      33
#
#    user_average_basket_r  time_since_last_order  up_order_rate  \
# 0               7.333333                     11       0.416667
# 1               7.333333                     11       0.833333
# 2               7.333333                     11       0.166667
# 3               7.333333                     11       0.666667
# 4               7.333333                     11       0.166667
#
#    up_orders_since_last_order  up_order_rate_since_first_order
# 0                           1                         0.416667
# 1                           0                         0.833333
# 2                           6                         0.250000
# 3                           0                         0.666667
# 4                           5                         0.285714
#
# [5 rows x 38 columns]

# %%
# Load Model
bst = xgb.Booster()
bst.load_model('xgb_4_500_0.2_6_10_0.7_0.76_0.95_2e-05_10_feats38')

# %%
pred = pd.DataFrame(bst.predict(xgb.DMatrix(df_test)))
print(pred.shape)
print(pred.head())

# df_test['order_id'] = test_order_id
# df_test['product_id'] = test_product_id
# del test_order_id, test_product_id
# df_test.head()
# Out:
# (4833292, 1)
#           0
# 0  0.324983
# 1  0.735323
# 2  0.074142
# 3  0.628608
# 4  0.088378

# %%
# %%time

df_test['pred'] = pred
TRESHOLD = 0.20

d = dict()
for row in df_test.itertuples():
    if row.pred > TRESHOLD:
        try:
            d[row.order_id] += ' ' + str(row.product_id)
        except:
            d[row.order_id] = str(row.product_id)

# Get test_orders with order_id
orders = pd.read_csv('../../data/orders.csv')
test_orders = orders[orders.eval_set == 'test']
del orders

for order in test_orders.order_id:
    if order not in d:
        d[order] = 'None'

del test_orders
# Out:
# CPU times: user 25.6 s, sys: 422 ms, total: 26.1 s
# Wall time: 26.1 s

# %%
sub = pd.DataFrame.from_dict(d, orient='index')
print(sub.shape)
sub.reset_index(inplace=True)
sub.columns = ['order_id', 'products']
sub.to_csv('sub.csv', index=False)
sub.head(10)
# Out:
# (75000, 1)
#    order_id                                           products
# 0   2774568          17668 39190 21903 47766 18599 43961 23650
# 1   1528013                                        38293 21903
# 2   1376945  33572 17706 28465 27959 30563 44632 24799 3465...
# 3   1356845                 11520 14992 7076 13176 28134 10863
# 4   2161313      11266 196 10441 12427 37710 48142 14715 27839
# 5   1416320  15872 5134 21903 24852 21137 48283 17948 21405...
# 6   1735923  17008 2192 196 15599 31487 15131 35123 12108 3...
# 7   1980631            13575 6184 9387 46061 41400 22362 13914
# 8   1411408                                        26452 22008
# 9   2940603          30592 19894 10339 44632 18531 14947 31615

# %% [markdown]
# # F1 Score Cross Validation

# %%
df_train['order_id'] = order_id
df_train['product_id'] = product_id
df_val = df_train.iloc[val_index, :]
df_val.shape
# Out:
# (847467, 41)

# %%
# Cross_Val to tune the threshold here.
df_val['pred'] = pred_val
TRESHOLD = 0.15
d = dict()
order_id_list = []
product_id_list = []
for row in df_val.itertuples():
    if row.pred > TRESHOLD:
        order_id_list.append(row.order_id)
        product_id_list.append(row.product_id)
        d[row.order_id] = 1
        

for order in df_val.order_id:
    if order not in d:
        order_id_list.append(order)
        product_id_list.append('None')

y_pred = pd.DataFrame(data={'order_id': order_id_list, 'product_id': product_id_list})
y_pred = y_pred.groupby('order_id')['product_id'].apply(list)
print(y_pred.shape)
y_pred.head()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# (171809, 2)
#    order_id product_id
# 0   1187899        196
# 1   1187899      13032
# 2   1187899      39657
# 3   1187899      12427
# 4   1187899      25133

# %%
y_true = df_val.groupby('order_id')['product_id'].apply(list)
print(y_true.shape)
y_true.head()
# Out:
# (13219,)
# order_id
# 96      [19904, 40706, 34949, 32139, 34050, 4461, 2067...
# 988     [9387, 38918, 46088, 19468, 13841, 38318, 3894...
# 1042    [24964, 26629, 11782, 34956, 21137, 30482, 248...
# 1275    [13409, 37570, 8518, 39558, 11046, 47209, 1236...
# 1865    [41696, 38849, 23234, 14715, 44292, 49605, 318...
# Name: product_id, dtype: object

# %%
def multilabel_fscore(y_true, y_pred):
    """
    ex1:
    y_true = [1, 2, 3]
    y_pred = [2, 3]
    return: 0.8
    
    ex2:
    y_true = ["None"]
    y_pred = [2, "None"]
    return: 0.666
    
    ex3:
    y_true = [4, 5, 6, 7]
    y_pred = [2, 4, 8, 9]
    return: 0.25
    
    """
    y_true, y_pred = set(y_true), set(y_pred)
    
    precision = sum([1 for i in y_pred if i in y_true]) / len(y_pred)
    
    recall = sum([1 for i in y_true if i in y_pred]) / len(y_true)
    
    if precision + recall == 0:
        return 0
    return (2 * precision * recall) / (precision + recall)

# Get train order set for (order_id, [product_id])
score = list(map(multilabel_fscore, y_true, y_pred))
print(np.sum(score) / len(y_true))
# np.sum(y_pred.index == y_true.index)
# Out:
# 0.388553893725
